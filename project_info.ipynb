# %% [markdown]
# ##

# %%
https://github.com/Rajbeer-singh2706/de-project.git

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
## ##
## Python Python 3.9 => 3. 10 also can be used 

## which python
## touch docker-compose.yml

# %%
docker compose up -d

# %%
## 
# pip install confluent_kafka simplejson pyspark
# pip freeze > requirements.txt

# %% [markdown]
# ## **IAM**

# %%
## User : 
# ADministratorAccess
# AmazonS3FullAccess
# AWSGLUEConsoleAcess
# IAMUserChangePassword

## Generate Access Secret key >> application running outside AWS

# %% [markdown]
# ## **S3**

# %%
# Bucket : spark-streaming-data ( publicly Acessible)
# Permission : Blcok public access : Blck all public acess : OFF

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Original command (deprecated versions)
# docker exec -it de-project-spark-master-1 /opt/spark/bin/spark-submit --master spark://spark-master:7077 --packages org.apache.spark:spark-sql-kafka-0_10_2.12:3.5.0,org.apache.hadoop:hadoop-aws:3.3.1,com.amazonaws:aws-java-sdk:1.11.469 jobs/spark-city.py

# Updated command with correct versions and cache
docker exec -it de-project-spark-master-1 /opt/spark/bin/spark-submit \
  --master spark://spark-master:7077 \
  --conf spark.jars.ivy=/tmp/.ivy2 \
  --packages org.apache.spark:spark-sql-kafka-0-10_2.12:3.4.1,org.apache.hadoop:hadoop-aws:3.3.1,com.amazonaws:aws-java-sdk:1.11.901 \
  /opt/spark/work-dir/spark-city.py

# %%
docker exec -it de-project-spark-master-1 bash -lc "which spark-submit || find / -name spark-submit 2>/dev/null | head -n 10"

# %%
# confirm the script exists inside the container (replace <CONTAINER_NAME>)
docker exec -it de-project-spark-master-1 ls -l /opt/spark/work-dir/spark-city.py

# %%
docker exec -it de-project-spark-master-1 bash
# Out:
#   Cell In[1], line 1
#     docker exec -it de-project-spark-master-1 bash
#            ^
# SyntaxError: Missing parentheses in call to 'exec'. Did you mean exec(...)?

# %%
docker compose down -v 
docker compose up -d

# %%
docker exec -it de-project-spark-master-1 /opt/spark/bin/spark-submit --master spark://spark-master:7077 --conf spark.jars.ivy=/tmp/.ivy2 --packages org.apache.spark:spark-sql-kafka-0-10_2.12:3.4.1,org.apache.hadoop:hadoop-aws:3.3.1,com.amazonaws:aws-java-sdk:1.11.901 /opt/spark/work-dir/spark-city.py
